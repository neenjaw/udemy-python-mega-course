# %%
import pandas
data = pandas.read_csv("volcanoes.csv")
data
# Out:
#                            Volcano Name               Country  \
# 0                                   Abu                 Japan
# 1                            Acamarachi                 Chile
# 2                            Acatenango             Guatemala
# 3                       Acigöl-Nevsehir                Turkey
# 4                                 Adams                   USA
# 5                        Adams Seamount         Pacific Ocean
# 6                               Adatara                 Japan
# 7                                  Adwa              Ethiopia
# 8                                Afderà              Ethiopia
# 9                               Agrigan       Mariana Islands
# 10                                 Agua             Guatemala
# 11                          Agua de Pau                Azores
# 12                             Aguilera                 Chile
# 13                                Agung  Lesser Sunda Islands
# ...

# %%
data.T.to_dict().values()
# Out:
# dict_values([{'Volcano Name': 'Abu', 'Country': 'Japan', 'Type': 'Shield', 'Latitude (dd)': 34.5, 'Longitude (dd)': 131.6, 'Elevation (m)': 641.0}, {'Volcano Name': 'Acamarachi', 'Country': 'Chile', 'Type': 'Stratovolcano', 'Latitude (dd)': -23.3, 'Longitude (dd)': -67.62, 'Elevation (m)': 6046.0}, {'Volcano Name': 'Acatenango', 'Country': 'Guatemala', 'Type': 'Stratovolcano', 'Latitude (dd)': 14.5, 'Longitude (dd)': -90.88, 'Elevation (m)': 3976.0}, {'Volcano Name': 'Acigöl-Nevsehir', 'Country': 'Turkey', 'Type': 'Caldera', 'Latitude (dd)': 38.57, 'Longitude (dd)': 34.52, 'Elevation (m)': 1689.0}, {'Volcano Name': 'Adams', 'Country': 'USA', 'Type': 'Stratovolcano', 'Latitude (dd)': 46.21, 'Longitude (dd)': -121.49, 'Elevation (m)': 3742.0}, {'Volcano Name': 'Adams Seamount', 'Country': 'Pacific Ocean', 'Type': 'Submarine', 'Latitude (dd)': -25.37, 'Longitude (dd)': -129.27, 'Elevation (m)': -39.0}, {'Volcano Name': 'Adatara', 'Country': 'Japan', 'Type': 'Stratovolcano', 'Latitude (d
# ...

# %%
data.to_dict('records')
# Out:
# [{'Volcano Name': 'Abu',
#   'Country': 'Japan',
#   'Type': 'Shield',
#   'Latitude (dd)': 34.5,
#   'Longitude (dd)': 131.6,
#   'Elevation (m)': 641.0},
#  {'Volcano Name': 'Acamarachi',
#   'Country': 'Chile',
#   'Type': 'Stratovolcano',
#   'Latitude (dd)': -23.3,
#   'Longitude (dd)': -67.62,
#   'Elevation (m)': 6046.0},
#  {'Volcano Name': 'Acatenango',
#   'Country': 'Guatemala',
#   'Type': 'Stratovolcano',
#   'Latitude (dd)': 14.5,
#   'Longitude (dd)': -90.88,
#   'Elevation (m)': 3976.0},
#  {'Volcano Name': 'Acigöl-Nevsehir',
#   'Country': 'Turkey',
#   'Type': 'Caldera',
#   'Latitude (dd)': 38.57,
#   'Longitude (dd)': 34.52,
#   'Elevation (m)': 1689.0},
#  {'Volcano Name': 'Adams',
#   'Country': 'USA',
#   'Type': 'Stratovolcano',
#   'Latitude (dd)': 46.21,
#   'Longitude (dd)': -121.49,
#   'Elevation (m)': 3742.0},
#  {'Volcano Name': 'Adams Seamount',
#   'Country': 'Pacific Ocean',
#   'Type': 'Submarine',
#   'Latitude (dd)': -25.37,
# ...
